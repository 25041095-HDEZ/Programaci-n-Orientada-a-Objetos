# %% [markdown]
# <a href="https://colab.research.google.com/github/25041095-HDEZ/Programaci-n-Orientada-a-Objetos/blob/main/Unidad%201/Programa_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Programacion Orientada a Objetos
#
# ## Unidad 1
#
# ### **Programa 1. Introduccion a Python**
#
# Nombre del alumno:_______________
#
# Facilitador: José Gabriel Rodriguez Rivas

# %%
# Variables en Python
x =20
print(x)
# Out:
# 20

# %%
print("La vaiable x es igual a", x)
# Out:
# La vaiable x es igual a 20

# %%
a =1000
b =3000
if a > b:
  print("a es mayor que b")
  print(a, " es mayor que ", b)
else:
  print("b es mayor que a")
  print(b, "es mayor que ", a)
# Out:
# b es mayor que a
# 3000 es mayor que  1000

# %%
 a =1
 while a <10:
  print(a)
  print("Dentro del While")
  a = a + 1
  print("Fuera del While")
# Out:
# 1
# Dentro del While
# Fuera del While
# 2
# Dentro del While
# Fuera del While
# 3
# Dentro del While
# Fuera del While
# 4
# Dentro del While
# Fuera del While
# 5
# Dentro del While
# Fuera del While
# 6
# Dentro del While
# Fuera del While
# 7
# Dentro del While
# Fuera del While
# 8
# Dentro del While
# Fuera del While
# 9
# Dentro del While
# Fuera del While

# %%
for i in range(5,11):
  print(i)
# Out:
# 5
# 6
# 7
# 8
# 9
# 10
